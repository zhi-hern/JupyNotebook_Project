# %% [markdown]
# ## Import library

# %%
import pandas as pd

# %% [markdown]
# ## Read data from .csv file
# - Data from https://www.kaggle.com/datasets/mohammadgharaei77/largest-2000-global-companies/data
#
# Ref: https://www.forbes.com/lists/global2000/

# %%
df = pd.read_csv('Largest-Companies.csv', encoding='ISO-8859-1')
df.head()
# Out:
#    Rank                                      Name  Sales  Profit  Assets  \
# 0     1                            JPMorgan Chase  252.9    50.0  4090.7
# 1     2                        Berkshire Hathaway  369.0    73.4  1070.0
# 2     3  Saudi Arabian Oil Company (Saudi Aramco)  489.1   116.9   661.5
# 3     4                                      ICBC  223.8    50.4  6586.0
# 4     5                           Bank of America  183.3    25.0  3273.8
#
#    Market Value                                Industry  Founded  \
# 0         588.1          Banking and Financial Services   2000.0
# 1         899.1                            Conglomerate   1839.0
# 2        1919.3  Construction- Chemicals- Raw Materials   1933.0
# 3         215.2          Banking and Financial Services   1984.0
# 4         307.3          Banking and Financial Services   1904.0
#
#                 Headquarters        Country                       CEO  \
# 0         New York- New York  United States               Jamie Dimon
# 1            Omaha- Nebraska  United States     Warren Edward Buffett
# 2                    Dhahran   Saudi Arabia  Amin bin Hasan Al-Nasser
# 3                    Beijing          China               Wang Jingwu
# 4  Charlotte- North Carolina  United States         Brian T. Moynihan
#
#    Employees
# 0   186751.0
# 1   396500.0
# 2    70000.0
# 3   427587.0
# 4   166140.0

# %% [markdown]
# ## Exploring the data imported

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2001 entries, 0 to 2000
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          2001 non-null   int64
#  1   Name          2001 non-null   object
#  2   Sales         2001 non-null   float64
#  3   Profit        2001 non-null   float64
#  4   Assets        2001 non-null   float64
#  5   Market Value  2001 non-null   float64
#  6   Industry      1999 non-null   object
#  7   Founded       1999 non-null   float64
#  8   Headquarters  1991 non-null   object
#  9   Country       2001 non-null   object
#  10  CEO           1970 non-null   object
#  11  Employees     1943 non-null   float64
# dtypes: float64(6), int64(1), object(5)
# memory usage: 187.7+ KB

# %% [markdown]
# ### Drop unnecessary columns for this analysis. (i.e: 'CEO', 'Employees')

# %%
df.drop(['CEO','Employees'], axis=1, inplace=True)
df.head()
# Out:
#    Rank                                      Name  Sales  Profit  Assets  \
# 0     1                            JPMorgan Chase  252.9    50.0  4090.7
# 1     2                        Berkshire Hathaway  369.0    73.4  1070.0
# 2     3  Saudi Arabian Oil Company (Saudi Aramco)  489.1   116.9   661.5
# 3     4                                      ICBC  223.8    50.4  6586.0
# 4     5                           Bank of America  183.3    25.0  3273.8
#
#    Market Value                                Industry  Founded  \
# 0         588.1          Banking and Financial Services   2000.0
# 1         899.1                            Conglomerate   1839.0
# 2        1919.3  Construction- Chemicals- Raw Materials   1933.0
# 3         215.2          Banking and Financial Services   1984.0
# 4         307.3          Banking and Financial Services   1904.0
#
#                 Headquarters        Country
# 0         New York- New York  United States
# 1            Omaha- Nebraska  United States
# 2                    Dhahran   Saudi Arabia
# 3                    Beijing          China
# 4  Charlotte- North Carolina  United States

# %% [markdown]
# ### Rename 'Sales', 'Profit', 'Assets' & 'Market Values' columns

# %%
df.rename(columns={'Sales':'Sales (in Billions)', 'Profit':'Profit (in Billions)',
                   'Assets':'Assets (in Billions)','Market Value':'Market Value (in Billions)'}, inplace=True)
df.head()
# Out:
#    Rank                                      Name  Sales (in Billions)  \
# 0     1                            JPMorgan Chase                252.9
# 1     2                        Berkshire Hathaway                369.0
# 2     3  Saudi Arabian Oil Company (Saudi Aramco)                489.1
# 3     4                                      ICBC                223.8
# 4     5                           Bank of America                183.3
#
#    Profit (in Billions)  Assets (in Billions)  Market Value (in Billions)  \
# 0                  50.0                4090.7                       588.1
# 1                  73.4                1070.0                       899.1
# 2                 116.9                 661.5                      1919.3
# 3                  50.4                6586.0                       215.2
# 4                  25.0                3273.8                       307.3
#
#                                  Industry  Founded               Headquarters  \
# 0          Banking and Financial Services   2000.0         New York- New York
# 1                            Conglomerate   1839.0            Omaha- Nebraska
# 2  Construction- Chemicals- Raw Materials   1933.0                    Dhahran
# 3          Banking and Financial Services   1984.0                    Beijing
# 4          Banking and Financial Services   1904.0  Charlotte- North Carolina
#
#          Country
# 0  United States
# 1  United States
# 2   Saudi Arabia
# 3          China
# 4  United States

# %% [markdown]
# ### Check for duplicates

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Sales (in Billions), Profit (in Billions), Assets (in Billions), Market Value (in Billions), Industry, Founded, Headquarters, Country]
# Index: []

# %% [markdown]
# ### Explore the various industries in the top 2000 companies

# %%
set(df['Industry'])
# Out:
# {'Aerospace & Defense',
#  'Airlines',
#  'Auto Brands',
#  'Auto Parts',
#  'Automotive',
#  'Automotive (Automotive and Suppliers)',
#  'Banking',
#  'Banking and Finance',
#  'Banking and Financial Services',
#  'Banks',
#  'Business Services & Supplies',
#  'Capital Goods',
#  'Casinos & Resorts',
#  'Chemicals',
#  'Clothing- Shoes- Sports Equipment',
#  'Conglomerate',
#  'Conglomerates',
#  'Construction',
#  'Construction- Chemicals- Raw Materials',
#  'Consumer Durables',
#  'Credit Card Companies',
#  'Cruise Lines',
#  'Data Analytics & Big Data',
#  'Department Stores',
#  'Diversified Financials',
#  'Drugs & Biotechnology',
#  'Engineering- Manufacturing',
#  'Fashion- Apparel- Shoes',
#  'Food & Drink',
#  'Food Drink & Tobacco',
#  'Food Markets',
#  'Food and Beverage',
#  'Food- Drink & Tobacco',
#  'Food- Soft Beverages- Alcohol & Tobacco',
#  'Health Care Equipment & Services',
#  'Healthcare & Social Services',
#  'Home & Furnishings',
#  'Home Improvement',
#  'Hotels',
#  'Hotels- Restaurants & Leisure',
#  'Household & Personal Products',
#  'IT Software & Services',
#  'Insurance',
#  'Iron & Steel',
#  'Materials',
#  'Media',
#  'Media & Advertising',
#  'Medical Devices & Products',
#  'National Car Dealers',
#  'Oil & Gas Operations',
#  'Oil & Gas Producers',
#  'Packaged Goods',
#  'Pharmaceuticals',
#  'Pharmacies',
#  'Professional Service',
#  'Professional Services',
#  'Quick- Fast- Casual',
#  'Real Estate',
#  'Restaurants',
#  'Retail and Wholesale',
#  'Retailing',
#  'Semiconductors',
#  'Semiconductors- Electronics- Electrical Engineering',
#  'Semiconductors- Electronics- Electrical Engineering- Technology Hardware & Equipment',
#  'Software & services',
#  'Software/Programming',
#  'Specialty',
#  'Superstores',
#  'Technology',
#  'Technology Hardware',
#  'Technology Hardware & Equipment',
#  'Telecommunications Services',
#  'Telecommunications Services- Cable Supplier',
#  'Tire Brands',
#  'Trading Companies',
#  'Transportation',
#  'Transportation and Logistics',
#  'Travel & Leisure',
#  'Utilities',
#  nan}

# %% [markdown]
# ## Structuring the data
# ### Aggregate similar industries into one for further analysis.
#
# - For example: 'Banking and Finance' to 'Banking', 'Banking and Financial Services' to 'Banking', 'Banks' to 'Banking'.

# %%
# Define the substring to find and the replacement string
replacement_dict = {'Auto Brands':'Automotive', 'Auto Parts':'Automotive', 'Automotive (Automotive and Suppliers)':'Automotive', 'National Car Dealers':'Automotive',
                    'Banking and Finance':'Banking','Banking and Financial Services':'Banking','Banks':'Banking',
                    'Cruise Lines':'Travel & Leisure',
                    'Conglomerates':'Conglomerate',
                    'Clothing- Shoes- Sports Equipment':'Apparel', 'Fashion- Apparel- Shoes':'Apparel',
                    'Credit Card Companies':'Diversified Financials',
                    'Data Analytics & Big Data':'IT Software & Services',
                    'Department Stores':'Retail and Wholesale',
                    'Food & Drink':'Food and Beverages', 'Food and Beverage':'Food and Beverages',
                    'Food Drink & Tobacco':'Food, Drink & Tobacco', 'Food- Drink & Tobacco':'Food, Drink & Tobacco', 'Food- Soft Beverages- Alcohol & Tobacco':'Food, Drink & Tobacco',
                    'Health Care Equipment & Services':'Healthcare', 'Healthcare & Social Services':'Healthcare', 'Medical Devices & Products':'Healthcare',
                    'Home & Furnishings':'Home Improvement',
                    'Hotels- Restaurants & Leisure':'Hotels', 
                    'Iron & Steel':'Materials', 
                    'Media & Advertising':'Media',
                    'Oil & Gas Operations':'Oil & Gas', 'Oil & Gas Producers':'Oil & Gas',
                    'Pharmacies':'Retail and Wholesale', 'Pharmaceuticals':'Healthcare',
                    'Professional Service':'Professional Services',
                    'Quick- Fast- Casual':'Restaurants',
                    'Semiconductors- Electronics- Electrical Engineering':'Semiconductors', 'Semiconductors- Electronics- Electrical Engineering- Technology Hardware & Equipment':'Semiconductors',
                    'Software & services':'IT Software & Services','Software/Programming':'IT Software & Services',
                    'Superstores':'Retail and Wholesale',
                    'Technology Hardware':'Technology', 'Technology Hardware & Equipment':'Technology',
                    'Telecommunications Services- Cable Supplier':'Telecommunications Services',
                    'Tire Brands':'Materials',
                    'Airlines':'Transportation'}

df['Industry'] = df['Industry'].replace(replacement_dict)
df.head()
# Out:
#    Rank                                      Name  Sales (in Billions)  \
# 0     1                            JPMorgan Chase                252.9
# 1     2                        Berkshire Hathaway                369.0
# 2     3  Saudi Arabian Oil Company (Saudi Aramco)                489.1
# 3     4                                      ICBC                223.8
# 4     5                           Bank of America                183.3
#
#    Profit (in Billions)  Assets (in Billions)  Market Value (in Billions)  \
# 0                  50.0                4090.7                       588.1
# 1                  73.4                1070.0                       899.1
# 2                 116.9                 661.5                      1919.3
# 3                  50.4                6586.0                       215.2
# 4                  25.0                3273.8                       307.3
#
#                                  Industry  Founded               Headquarters  \
# 0                                 Banking   2000.0         New York- New York
# 1                            Conglomerate   1839.0            Omaha- Nebraska
# 2  Construction- Chemicals- Raw Materials   1933.0                    Dhahran
# 3                                 Banking   1984.0                    Beijing
# 4                                 Banking   1904.0  Charlotte- North Carolina
#
#          Country
# 0  United States
# 1  United States
# 2   Saudi Arabia
# 3          China
# 4  United States

# %%
set(df['Industry'])
# Out:
# {'Aerospace & Defense',
#  'Apparel',
#  'Automotive',
#  'Banking',
#  'Business Services & Supplies',
#  'Capital Goods',
#  'Casinos & Resorts',
#  'Chemicals',
#  'Conglomerate',
#  'Construction',
#  'Construction- Chemicals- Raw Materials',
#  'Consumer Durables',
#  'Diversified Financials',
#  'Drugs & Biotechnology',
#  'Engineering- Manufacturing',
#  'Food Markets',
#  'Food and Beverages',
#  'Food, Drink & Tobacco',
#  'Healthcare',
#  'Home Improvement',
#  'Hotels',
#  'Household & Personal Products',
#  'IT Software & Services',
#  'Insurance',
#  'Materials',
#  'Media',
#  'Oil & Gas',
#  'Packaged Goods',
#  'Professional Services',
#  'Real Estate',
#  'Restaurants',
#  'Retail and Wholesale',
#  'Retailing',
#  'Semiconductors',
#  'Specialty',
#  'Technology',
#  'Telecommunications Services',
#  'Trading Companies',
#  'Transportation',
#  'Transportation and Logistics',
#  'Travel & Leisure',
#  'Utilities',
#  nan}

# %% [markdown]
# ## Validating the data
# ### Replace null values in 'Industry' column
# - Find out null values and fill them by searching the web.

# %%
df[df['Industry'].isnull()]
# Out:
#       Rank       Name  Sales (in Billions)  Profit (in Billions)  \
# 1276  1277  Solventum                  8.2                 1.300
# 1367  1368    Veralto                  5.0                 0.798
#
#       Assets (in Billions)  Market Value (in Billions) Industry  Founded  \
# 1276                  14.7                        10.8      NaN      NaN
# 1367                   5.7                        24.3      NaN      NaN
#
#        Headquarters        Country
# 1276      Minnesota  United States
# 1367  Massachusetts  United States

# %% [markdown]
# - Solventum is a healthcare, industrial, and manufacturing company, founded on 2023.<br>
# - Veralto is a company focus on technology solutions, founded on 2022.

# %%
df.loc[1276,'Industry']='Healthcare'
df.loc[1276, 'Founded']= 2023 
df[df['Name']=='Solventum']
# Out:
#       Rank       Name  Sales (in Billions)  Profit (in Billions)  \
# 1276  1277  Solventum                  8.2                   1.3
#
#       Assets (in Billions)  Market Value (in Billions)    Industry  Founded  \
# 1276                  14.7                        10.8  Healthcare   2023.0
#
#      Headquarters        Country
# 1276    Minnesota  United States

# %%
df.loc[1367,'Industry']='Technology'
df.loc[1367, 'Founded']= 2022 
df[df['Name']=='Veralto']
# Out:
#       Rank     Name  Sales (in Billions)  Profit (in Billions)  \
# 1367  1368  Veralto                  5.0                 0.798
#
#       Assets (in Billions)  Market Value (in Billions)    Industry  Founded  \
# 1367                   5.7                        24.3  Technology   2022.0
#
#        Headquarters        Country
# 1367  Massachusetts  United States

# %% [markdown]
# ## Explore the average profit for each industries
# - Count was identified for each industry was identidfied to understand the sample size that was sed to calculate the average profit.

# %%
industry = df[['Industry']].value_counts().reset_index(name='Count')
industry
# Out:
#                                   Industry  Count
# 0                                  Banking    354
# 1                   Diversified Financials    117
# 2                                Utilities    103
# 3                                Insurance    102
# 4                             Construction     85
# 5                   IT Software & Services     84
# 6   Construction- Chemicals- Raw Materials     83
# 7                    Food, Drink & Tobacco     82
# 8                           Semiconductors     67
# 9               Engineering- Manufacturing     64
# 10                               Materials     63
# 11            Business Services & Supplies     62
# 12                               Oil & Gas     61
# 13                          Transportation     57
# 14                   Drugs & Biotechnology     56
# 15                              Healthcare     51
# 16                    Retail and Wholesale     46
# 17             Telecommunications Services     44
# 18                           Capital Goods     42
# 19                       Consumer Durables     37
# 20                              Automotive     37
# 21                               Chemicals     36
# 22                               Retailing     35
# 23                              Technology     27
# 24                     Aerospace & Defense     23
# 25                                   Media     22
# 26                       Trading Companies     21
# 27            Transportation and Logistics     19
# 28                            Conglomerate     19
# 29                            Food Markets     17
# 30                                 Apparel     16
# 31                   Professional Services     12
# 32           Household & Personal Products     10
# 33                                  Hotels     10
# 34                          Packaged Goods      9
# 35                        Travel & Leisure      9
# 36                             Restaurants      6
# 37                             Real Estate      4
# 38                               Specialty      3
# 39                        Home Improvement      2
# 40                       Casinos & Resorts      2
# 41                      Food and Beverages      2

# %%
avg_profit = df.groupby('Industry').agg({'Industry':'count','Profit (in Billions)':'mean'})\
            .sort_values(by='Profit (in Billions)',ascending=False).rename(columns={'Industry':'Count','Profit (in Billions)':'Avg Profit'})\
            .reset_index()
avg_profit
# Out:
#                                   Industry  Count  Avg Profit
# 0                             Conglomerate     19    5.692979
# 1                                Specialty      3    5.500000
# 2   Construction- Chemicals- Raw Materials     83    4.922052
# 3                           Semiconductors     67    4.256100
# 4                               Automotive     37    4.223292
# 5                   IT Software & Services     84    4.044294
# 6                           Packaged Goods      9    4.032856
# 7                     Retail and Wholesale     46    3.150989
# 8                                  Banking    354    3.079124
# 9                              Restaurants      6    2.873367
# 10                               Oil & Gas     61    2.539148
# 11                                 Apparel     16    2.335662
# 12                   Professional Services     12    2.204550
# 13                        Travel & Leisure      9    2.119556
# 14                   Drugs & Biotechnology     56    2.103721
# 15                               Insurance    102    2.061397
# 16                       Consumer Durables     37    2.013927
# 17             Telecommunications Services     44    1.888509
# 18                     Aerospace & Defense     23    1.852604
# 19              Engineering- Manufacturing     64    1.813770
# 20                                   Media     22    1.804827
# 21            Transportation and Logistics     19    1.757005
# 22                        Home Improvement      2    1.674900
# 23            Business Services & Supplies     62    1.563479
# 24                              Healthcare     51    1.492376
# 25                               Utilities    103    1.441598
# 26                   Food, Drink & Tobacco     82    1.441150
# 27                             Real Estate      4    1.348925
# 28                  Diversified Financials    117    1.306723
# 29                          Transportation     57    1.274267
# 30                      Food and Beverages      2    1.028500
# 31                               Materials     63    0.955530
# 32                       Casinos & Resorts      2    0.877500
# 33           Household & Personal Products     10    0.826070
# 34                           Capital Goods     42    0.820079
# 35                            Food Markets     17    0.735771
# 36                               Retailing     35    0.735060
# 37                            Construction     85    0.729808
# 38                                  Hotels     10    0.688590
# 39                       Trading Companies     21    0.685133
# 40                              Technology     27    0.638700
# 41                               Chemicals     36    0.611103

# %% [markdown]
# - Findings: <br>
# (i)  Finance companies (i.e.: `Banking` and `Diversified Financials`) dominate the top 2000 companies' list. <br>
# (ii) Top 5 most profitable industries are: `Conglomerate`, `Specialty`, `Construction- Chemicals- Raw Materials`, `Semiconductors` & `Automotive`.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Plot boxplot for every industry to determine any trends

# %%
plt.figure(figsize=[50,6]) 
ax1 = sns.boxplot(x='Industry', y='Profit (in Billions)', hue='Industry', 
                  data=df,showfliers=False)
plt.xticks(rotation=45, horizontalalignment='right')
plt.title('Boxplot of Profit for Every Industry',fontsize=20)
plt.axhline(y=0) 
plt.show()

# %% [markdown]
# - Findings: <br>
# (i)  Most of the companies in the `Packaging Goods` and `Specialty` are thriving and profitable. <br>
# (ii) `Construction- Chemicals- Raw Materials`'s Profits can have a big fluctuation in profits between companies.

# %% [markdown]
# ## **Explore distribution of the year established for top 2000 companies**

# %%
df['Founded']=df['Founded'].astype('int')

# %%
df['Founded'].value_counts().reset_index()
# Out:
#      Founded  count
# 0       1997     54
# 1       1998     42
# 2       1999     42
# 3       1996     37
# 4       1995     37
# ..       ...    ...
# 211     1809      1
# 212     1806      1
# 213     1803      1
# 214     1816      1
# 215    20047      1
#
# [216 rows x 2 columns]

# %% [markdown]
# ## Cleaning the data
# ### Identify outliers

# %%
sns.boxplot(x='Founded',data=df)
plt.show()

# %% [markdown]
# - There's a outlier at 20,000 ++ years in the year `'Founded'` column.
# - `Describe` method was used to identify the value of the outlier.

# %%
df['Founded'].describe()
# Out:
# count     2001.000000
# mean      1966.464268
# std        407.647503
# min       1472.000000
# 25%       1926.000000
# 50%       1973.000000
# 75%       1997.000000
# max      20047.000000
# Name: Founded, dtype: float64

# %%
df[df['Founded']==20047]
# Out:
#       Rank                             Name  Sales (in Billions)  \
# 1980  1981  China Merchants Energy Shipping                  3.7
#
#       Profit (in Billions)  Assets (in Billions)  Market Value (in Billions)  \
# 1980                0.7099                   8.8                        10.3
#
#             Industry  Founded Headquarters Country
# 1980  Transportation    20047     Shanghai   China

# %% [markdown]
# - By searching the web, able to found out that the year `China Merchants Energy Shipping` was established is `2004`.

# %%
df.loc[1980,'Founded']=2004
df.loc[1980]
# Out:
# Rank                                                     1981
# Name                          China Merchants Energy Shipping
# Sales (in Billions)                                       3.7
# Profit (in Billions)                                   0.7099
# Assets (in Billions)                                      8.8
# Market Value (in Billions)                               10.3
# Industry                                       Transportation
# Founded                                                  2004
# Headquarters                                         Shanghai
# Country                                                 China
# Name: 1980, dtype: object

# %%
year_est=df['Founded'].value_counts().reset_index()
year_est.head()
# Out:
#    Founded  count
# 0     1997     54
# 1     1998     42
# 2     1999     42
# 3     1996     37
# 4     1995     37

# %%
plt.figure(figsize=[35,10])
ax = sns.barplot(x='Founded',y='count',data=year_est)
plt.xlabel('Year Founded')
plt.ylabel('No. of Companies')
ax.tick_params(axis='x', rotation=90)
plt.title('No.of companies based on Year Founded', fontsize=25)
plt.show()

# %% [markdown]
# - Conclusion: The distribution shows that more companies that established during the 1990s to 2000s are good at staying relevant till today.

# %% [markdown]
# ## **_Evaluate Sales Performance_**
# ### Calculate Gross Profit Margin (GPM) which indicates the efficiency of production and pricing.
#
# ![image.png](attachment:c5f980ea-f2e4-48a6-a58b-7ba2e19fe32f.png)
#
# - **Assumption 1: Total Revenue = `'Sales'` in data**
# - **Assumption 2: Gross Profit = `'Profit'` in data**
# - Gross Profit Margin (GPM) = Profit/Sales x 100%
# - Top 10 companies with the highest GPM were identified.
# - Top 10 industries with the highest GPM were identified.
# - Top companies in these industries were determined.
# <br>
#
# Ref: https://ramp.com/blog/how-to-measure-company-financial-performance

# %%
GPM = df[['Name','Sales (in Billions)','Profit (in Billions)','Industry','Country']]
GPM.insert(3,'Gross Profit Margin',df['Profit (in Billions)']/df['Sales (in Billions)']*100,True)
GPM.head()
# Out:
#                                        Name  Sales (in Billions)  \
# 0                            JPMorgan Chase                252.9
# 1                        Berkshire Hathaway                369.0
# 2  Saudi Arabian Oil Company (Saudi Aramco)                489.1
# 3                                      ICBC                223.8
# 4                           Bank of America                183.3
#
#    Profit (in Billions)  Gross Profit Margin  \
# 0                  50.0            19.770660
# 1                  73.4            19.891599
# 2                 116.9            23.901043
# 3                  50.4            22.520107
# 4                  25.0            13.638843
#
#                                  Industry        Country
# 0                                 Banking  United States
# 1                            Conglomerate  United States
# 2  Construction- Chemicals- Raw Materials   Saudi Arabia
# 3                                 Banking          China
# 4                                 Banking  United States

# %%
GPM = GPM.sort_values(by='Gross Profit Margin',ascending=False).reset_index()
GPM.drop('index',axis=1,inplace=True)
GPM.insert(0,'Rank (in GPM)', GPM.index+1, False)
GPM.head()
# Out:
#    Rank (in GPM)                         Name  Sales (in Billions)  \
# 0              1             Roivant Sciences                0.123
# 1              2                     3i Group                0.707
# 2              3        Power Assets Holdings                0.165
# 3              4  Bajaj Holdings & Investment                0.207
# 4              5      Sichuan Chuantou Energy                0.201
#
#    Profit (in Billions)  Gross Profit Margin                Industry  \
# 0                4.5000          3658.536585   Drugs & Biotechnology
# 1                4.8000           678.925035  Diversified Financials
# 2                0.7668           464.727273               Utilities
# 3                0.8778           424.057971  Diversified Financials
# 4                0.6327           314.776119               Utilities
#
#           Country
# 0  United Kingdom
# 1  United Kingdom
# 2       Hong Kong
# 3           India
# 4           China

# %% [markdown]
# ### Top 10 companies that have the highest Gross Profit Margin.

# %%
GPM.head(10)
# Out:
#    Rank (in GPM)                          Name  Sales (in Billions)  \
# 0              1              Roivant Sciences                0.123
# 1              2                      3i Group                0.707
# 2              3         Power Assets Holdings                0.165
# 3              4   Bajaj Holdings & Investment                0.207
# 4              5       Sichuan Chuantou Energy                0.201
# 5              6                Industrivarden                1.000
# 6              7                   Investor AB                7.400
# 7              8                        Itaúsa                1.500
# 8              9  Jiangxi Zhengbang Technology                0.857
# 9             10                           CTP                0.786
#
#    Profit (in Billions)  Gross Profit Margin                Industry  \
# 0                4.5000          3658.536585   Drugs & Biotechnology
# 1                4.8000           678.925035  Diversified Financials
# 2                0.7668           464.727273               Utilities
# 3                0.8778           424.057971  Diversified Financials
# 4                0.6327           314.776119               Utilities
# 5                3.0000           300.000000  Diversified Financials
# 6               15.2000           205.405405  Diversified Financials
# 7                2.7000           180.000000  Diversified Financials
# 8                1.3000           151.691949   Food, Drink & Tobacco
# 9                1.0000           127.226463            Construction
#
#           Country
# 0  United Kingdom
# 1  United Kingdom
# 2       Hong Kong
# 3           India
# 4           China
# 5          Sweden
# 6          Sweden
# 7          Brazil
# 8           China
# 9     Netherlands

# %% [markdown]
# #### Findings:
# - The unusually high `'Profit'` by `Roivant Sciences` compared to its `'Sales'` is due to Roche completed acquisition of Telavant from Roivant. <br>
# - Roivant gain 5.35 billion on the sale of Telavant net assets. <br>
#
# Ref: <br>
# https://investor.roivant.com/news-releases/news-release-details/roivant-reports-financial-results-fourth-quarter-and-fiscal-0 <br>
# https://investor.roivant.com/news-releases/news-release-details/roche-completes-acquisition-telavant-roivant-including-rights

# %% [markdown]
# ### Top 10 industries that have the highest Gross Profit Margin.

# %%
GPM.groupby(by='Industry').agg({'Industry':'count','Gross Profit Margin':'mean'}).sort_values(by='Gross Profit Margin',ascending=False)\
                         .rename(columns={'Industry':'Count','Gross Profit Margin':'Avg Gross Profit Margin'}).head(10)
# Out:
#                         Count  Avg Gross Profit Margin
# Industry
# Drugs & Biotechnology      56                75.652422
# Diversified Financials    117                34.710005
# Real Estate                 4                21.460525
# Utilities                 103                18.162450
# Banking                   354                17.021676
# Restaurants                 6                16.895907
# Transportation             57                15.489887
# Semiconductors             67                14.706271
# Travel & Leisure            9                14.695441
# Hotels                     10                13.463334

# %% [markdown]
# #### Top 10 GPM in Drugs & Biotechnology

# %%
GPM[GPM['Industry']=='Drugs & Biotechnology'].sort_values(by='Gross Profit Margin',ascending=False).head(10)
# Out:
#      Rank (in GPM)                                   Name  \
# 0                1                       Roivant Sciences
# 50              51                    United Therapeutics
# 63              64                 Vertex Pharmaceuticals
# 75              76                               Shionogi
# 78              79                         Royalty Pharma
# 123            124                               Novartis
# 136            137                                 Genmab
# 145            146              Regeneron Pharmaceuticals
# 178            179  Zhangzhou Pientzehuang Pharmaceutical
# 183            184                                 Zoetis
#
#      Sales (in Billions)  Profit (in Billions)  Gross Profit Margin  \
# 0                  0.123                4.5000          3658.536585
# 50                 2.500                1.1000            44.000000
# 63                10.200                4.0000            39.215686
# 75                 3.000                1.1000            36.666667
# 78                 2.200                0.7995            36.340909
# 123               48.700               15.2000            31.211499
# 136                2.600                0.7929            30.496154
# 145               13.100                3.9000            29.770992
# 178                1.500                0.4186            27.906667
# 183                8.700                2.4000            27.586207
#
#                   Industry         Country
# 0    Drugs & Biotechnology  United Kingdom
# 50   Drugs & Biotechnology   United States
# 63   Drugs & Biotechnology   United States
# 75   Drugs & Biotechnology           Japan
# 78   Drugs & Biotechnology   United States
# 123  Drugs & Biotechnology     Switzerland
# 136  Drugs & Biotechnology         Denmark
# 145  Drugs & Biotechnology   United States
# 178  Drugs & Biotechnology           China
# 183  Drugs & Biotechnology   United States

# %% [markdown]
# #### Top 10 GPM in Diversified Financials

# %%
GPM[GPM['Industry']=='Diversified Financials'].sort_values(by='Gross Profit Margin',ascending=False).head(10)
# Out:
#     Rank (in GPM)                         Name  Sales (in Billions)  \
# 1               2                     3i Group                0.707
# 3               4  Bajaj Holdings & Investment                0.207
# 5               6               Industrivarden                1.000
# 6               7                  Investor AB                7.400
# 7               8                       Itaúsa                1.500
# 13             14                         EXOR                2.800
# 14             15            Jackson Financial                3.600
# 16             17       Jio Financial Services                0.224
# 18             19                      Eurazeo                2.400
# 20             21              VICI Properties                3.700
#
#     Profit (in Billions)  Gross Profit Margin                Industry  \
# 1                 4.8000           678.925035  Diversified Financials
# 3                 0.8778           424.057971  Diversified Financials
# 5                 3.0000           300.000000  Diversified Financials
# 6                15.2000           205.405405  Diversified Financials
# 7                 2.7000           180.000000  Diversified Financials
# 13                2.5000            89.285714  Diversified Financials
# 14                3.2000            88.888889  Diversified Financials
# 16                0.1938            86.517857  Diversified Financials
# 18                2.0000            83.333333  Diversified Financials
# 20                2.6000            70.270270  Diversified Financials
#
#            Country
# 1   United Kingdom
# 3            India
# 5           Sweden
# 6           Sweden
# 7           Brazil
# 13     Netherlands
# 14   United States
# 16           India
# 18          France
# 20   United States

# %% [markdown]
# #### Top 10 GPM in Utilities

# %%
GPM[GPM['Industry']=='Utilities'].sort_values(by='Gross Profit Margin',ascending=False).head(10)
# Out:
#      Rank (in GPM)                     Name  Sales (in Billions)  \
# 2                3    Power Assets Holdings                0.165
# 4                5  Sichuan Chuantou Energy                0.201
# 58              59      Adani Power Limited                6.100
# 73              74            National Grid               25.400
# 85              86      China Yangtze Power               10.700
# 90              91     Brookfield Renewable                4.000
# 98              99      Power Grid of India                5.600
# 122            123           NextEra Energy               24.000
# 140            141      Essential Utilities                1.900
# 175            176                    Terna                3.400
#
#      Profit (in Billions)  Gross Profit Margin   Industry         Country
# 2                  0.7668           464.727273  Utilities       Hong Kong
# 4                  0.6327           314.776119  Utilities           China
# 58                 2.5000            40.983607  Utilities           India
# 73                 9.4000            37.007874  Utilities  United Kingdom
# 85                 3.8000            35.514019  Utilities           China
# 90                 1.4000            35.000000  Utilities   United States
# 98                 1.9000            33.928571  Utilities           India
# 122                7.5000            31.250000  Utilities   United States
# 140                0.5726            30.136842  Utilities   United States
# 175                0.9572            28.152941  Utilities           Italy

# %% [markdown]
# #### Top 10 GPM in Banking

# %%
GPM[GPM['Industry']=='Banking'].sort_values(by='Gross Profit Margin',ascending=False).head(10)
# Out:
#     Rank (in GPM)                         Name  Sales (in Billions)  \
# 17             18  Schweizerische Nationalbank                 38.7
# 25             26           Qatar Islamic Bank                  2.0
# 28             29                       Keppel                  5.2
# 42             43                   Mastercard                 25.7
# 49             50                 Mashreq Bank                  5.2
# 51             52            Bank Central Asia                  7.5
# 59             60                    UniCredit                 26.5
# 66             67       Nova Ljubljanska Banka                  1.6
# 69             70      Bank of Cyprus Holdings                  1.5
# 76             77                 Novo Nordisk                 35.5
#
#     Profit (in Billions)  Gross Profit Margin Industry               Country
# 17               32.4000            83.720930  Banking           Switzerland
# 25                1.2000            60.000000  Banking                 Qatar
# 28                3.0000            57.692308  Banking             Singapore
# 42               11.8000            45.914397  Banking         United States
# 49                2.3000            44.230769  Banking  United Arab Emirates
# 51                3.3000            44.000000  Banking             Indonesia
# 59               10.8000            40.754717  Banking                 Italy
# 66                0.6187            38.668750  Banking              Slovenia
# 69                0.5695            37.966667  Banking                Cyprus
# 76               13.0000            36.619718  Banking               Denmark

# %% [markdown]
# #### Top 10 GPM in Transportation

# %%
GPM[GPM['Industry']=='Transportation'].sort_values(by='Gross Profit Margin',ascending=False).head(10)
# Out:
#      Rank (in GPM)                                               Name  \
# 11              12                                            Euronav
# 22              23  China Merchants Expressway Network & Technolog...
# 35              36                      China Merchants Port Holdings
# 81              82                        Shanghai International Port
# 105            106                                               Aena
# 110            111                          Canadian National Railway
# 134            135                Adani Ports & Special Economic Zone
# 146            147                       Zhejiang Expressway Co. Ltd.
# 149            150                Beijing-Shanghai High-Speed Railway
# 168            169                       Canadian Pacific Kansas City
#
#      Sales (in Billions)  Profit (in Billions)  Gross Profit Margin  \
# 11                   1.1                1.2000           109.090909
# 22                   1.5                0.9358            62.386667
# 35                   1.5                0.7961            53.073333
# 81                   5.3                1.9000            35.849057
# 105                  5.4                1.8000            33.333333
# 110                 13.5                4.4000            32.592593
# 134                  3.2                0.9796            30.612500
# 146                  2.4                0.7067            29.445833
# 149                  5.8                1.7000            29.310345
# 168                 10.2                2.9000            28.431373
#
#            Industry    Country
# 11   Transportation    Belgium
# 22   Transportation      China
# 35   Transportation  Hong Kong
# 81   Transportation      China
# 105  Transportation      Spain
# 110  Transportation     Canada
# 134  Transportation      India
# 146  Transportation      China
# 149  Transportation      China
# 168  Transportation     Canada

# %% [markdown]
# ## **_Evaluate Asset Management_**
# ### Calculate Asset Turnover Ratio (ATR) which measures the efficiency with which a company uses its assets to produce sales.
# ![image.png](attachment:d369b70f-53ba-4462-9b7e-9ffe870c77d9.png)
# - **Assumption 1: Net Sales = `'Sales'` in data**
# - **Assumption 2: Average Total Assets = `'Assets'` in data**
# - Asset Turnover Ratio (ATR) = Sales/Assets
#
# Ref: https://corporatefinanceinstitute.com/resources/accounting/asset-turnover-ratio/

# %%
ATR = df[['Name','Sales (in Billions)','Assets (in Billions)','Industry','Country']]
ATR.insert(3,'Asset Turnover Ratio',df['Sales (in Billions)']/df['Assets (in Billions)'],True)
ATR.head()
# Out:
#                                        Name  Sales (in Billions)  \
# 0                            JPMorgan Chase                252.9
# 1                        Berkshire Hathaway                369.0
# 2  Saudi Arabian Oil Company (Saudi Aramco)                489.1
# 3                                      ICBC                223.8
# 4                           Bank of America                183.3
#
#    Assets (in Billions)  Asset Turnover Ratio  \
# 0                4090.7              0.061823
# 1                1070.0              0.344860
# 2                 661.5              0.739380
# 3                6586.0              0.033981
# 4                3273.8              0.055990
#
#                                  Industry        Country
# 0                                 Banking  United States
# 1                            Conglomerate  United States
# 2  Construction- Chemicals- Raw Materials   Saudi Arabia
# 3                                 Banking          China
# 4                                 Banking  United States

# %% [markdown]
# ### Top 10 companies that have the highest Asset Turnover Ratio

# %%
ATR = ATR.sort_values(by='Asset Turnover Ratio',ascending=False).reset_index()
ATR.drop('index',axis=1,inplace=True)
ATR.insert(0,'Rank (in ATR)', GPM.index+1, False)
ATR.head(10)
# Out:
#    Rank (in ATR)                           Name  Sales (in Billions)  \
# 0              1                 Rajesh Exports                 36.9
# 1              2            World Fuel Services                 46.2
# 2              3                     Murphy USA                 21.3
# 3              4                Cardinal Health                220.6
# 4              5                       McKesson                309.0
# 5              6         Performance Food Group                 58.0
# 6              7     Zheshang Development Group                 28.5
# 7              8                        Cencora                276.5
# 8              9  Ningbo Jintian Copper (Group)                 15.5
# 9             10           United Natural Foods                 30.3
#
#    Assets (in Billions)  Asset Turnover Ratio               Industry  \
# 0                   2.3             16.043478      Consumer Durables
# 1                   7.2              6.416667      Trading Companies
# 2                   4.3              4.953488              Retailing
# 3                  45.9              4.806100   Retail and Wholesale
# 4                  67.4              4.584570             Healthcare
# 5                  13.1              4.427481         Transportation
# 6                   6.5              4.384615      Trading Companies
# 7                  63.9              4.327074   Retail and Wholesale
# 8                   3.6              4.305556              Materials
# 9                   7.7              3.935065  Food, Drink & Tobacco
#
#          Country
# 0          India
# 1  United States
# 2  United States
# 3  United States
# 4  United States
# 5  United States
# 6          China
# 7  United States
# 8          China
# 9  United States

# %% [markdown]
# ### Top 10 industries that have the highest Asset Turnover Ratio

# %%
ATR.groupby(by='Industry').agg({'Industry':'count','Asset Turnover Ratio':'mean'}).sort_values(by='Asset Turnover Ratio',ascending=False)\
                         .rename(columns={'Industry':'Count','Asset Turnover Ratio':'Avg Asset Turnover Ratio'}).head(10)
# Out:
#                       Count  Avg Asset Turnover Ratio
# Industry
# Trading Companies        21                  1.903901
# Retail and Wholesale     46                  1.665346
# Food Markets             17                  1.581739
# Retailing                35                  1.437454
# Consumer Durables        37                  1.372129
# Restaurants               6                  1.282762
# Home Improvement          2                  1.227302
# Technology               27                  1.140665
# Specialty                 3                  1.137206
# Apparel                  16                  0.987017

# %% [markdown]
# - Findings: Industries that have high Asset Turnover Ratio usually involve products that are well-accessible by the public.

# %% [markdown]
# ## **_Profitability Analysis_**
# ### Calculate Return on Assets (ROA) which indicates how effectively a company utilizes its assets to generate profit, reflecting operational efficiency and asset management.
# ![image.png](attachment:ffb6011b-d9fa-4d4e-b4da-8eaf81b80915.png)
#
# - **Assumption 1: Net Income = `'Profit'` in data**
# - **Assumption 2: Total Assets = `'Assets'` in data**
# - Return on Assets (ROA) = Profit/Assets
#
# Ref: https://www.investopedia.com/terms/r/returnonassets.asp

# %%
ROA = df[['Name','Profit (in Billions)','Assets (in Billions)','Industry','Country']]
ROA.insert(3,'Return on Assets',df['Profit (in Billions)']/df['Assets (in Billions)'],True)
ROA.head()
# Out:
#                                        Name  Profit (in Billions)  \
# 0                            JPMorgan Chase                  50.0
# 1                        Berkshire Hathaway                  73.4
# 2  Saudi Arabian Oil Company (Saudi Aramco)                 116.9
# 3                                      ICBC                  50.4
# 4                           Bank of America                  25.0
#
#    Assets (in Billions)  Return on Assets  \
# 0                4090.7          0.012223
# 1                1070.0          0.068598
# 2                 661.5          0.176720
# 3                6586.0          0.007653
# 4                3273.8          0.007636
#
#                                  Industry        Country
# 0                                 Banking  United States
# 1                            Conglomerate  United States
# 2  Construction- Chemicals- Raw Materials   Saudi Arabia
# 3                                 Banking          China
# 4                                 Banking  United States

# %% [markdown]
# ### Top 10 companies that have the highest Return on Assets

# %%
ROA = ROA.sort_values(by='Return on Assets',ascending=False).reset_index()
ROA.drop('index',axis=1,inplace=True)
ROA.insert(0,'Rank (in ROA)', GPM.index+1, False)
ROA.head(10)
# Out:
#    Rank (in ROA)                          Name  Profit (in Billions)  \
# 0              1              Roivant Sciences                4.5000
# 1              2  Jiangxi Zhengbang Technology                1.3000
# 2              3                      VeriSign                0.8330
# 3              4                        NVIDIA               29.8000
# 4              5         Cogent Communications                1.2000
# 5              6               Diebold Nixdorf                1.5000
# 6              7               Bayan Resources                1.0000
# 7              8                       Euronav                1.2000
# 8              9                Domino's Pizza                0.5402
# 9             10     Tata Consultancy Services                5.5000
#
#    Assets (in Billions)  Return on Assets                     Industry  \
# 0                   7.3          0.616438        Drugs & Biotechnology
# 1                   2.5          0.520000        Food, Drink & Tobacco
# 2                   1.7          0.490000       IT Software & Services
# 3                  65.7          0.453577               Semiconductors
# 4                   3.1          0.387097  Telecommunications Services
# 5                   3.9          0.384615                   Technology
# 6                   2.9          0.344828                    Materials
# 7                   3.7          0.324324               Transportation
# 8                   1.7          0.317765                  Restaurants
# 9                  17.6          0.312500       IT Software & Services
#
#           Country
# 0  United Kingdom
# 1           China
# 2   United States
# 3   United States
# 4   United States
# 5         Germany
# 6       Indonesia
# 7         Belgium
# 8   United States
# 9           India

# %% [markdown]
# ### Top 10 industries that have the highest Return on Assets

# %%
ROA.groupby(by='Industry').agg({'Industry':'count','Return on Assets':'mean'}).sort_values(by='Return on Assets',ascending=False)\
                         .rename(columns={'Industry':'Count','Return on Assets':'Avg Return on Assets'}).head(10)
# Out:
#                        Count  Avg Return on Assets
# Industry
# Restaurants                6              0.186986
# Home Improvement           2              0.140886
# Specialty                  3              0.097275
# Apparel                   16              0.095677
# Professional Services     12              0.095050
# Semiconductors            67              0.094406
# Food and Beverages         2              0.092092
# Hotels                    10              0.083350
# Travel & Leisure           9              0.080044
# Retail and Wholesale      46              0.078876

# %% [markdown]
# ## Company analysis based on Gross Profit Margin (GPM), Asset Turnover Ratio (ATR) and Return on Assets (ROA)
# ### Analysis based on companies' performance on GPM, ATR and ROA
# - Merge GPM, ATR, ROA dataframe and compare the ranking which reflect their performance in the respective index.

# %%
analysis = pd.merge(GPM[['Rank (in GPM)','Name','Sales (in Billions)','Profit (in Billions)','Gross Profit Margin','Industry','Country']],
                    ATR[['Rank (in ATR)','Name','Assets (in Billions)','Asset Turnover Ratio']],
                    how='inner', on='Name')
analysis.head()
# Out:
#    Rank (in GPM)                         Name  Sales (in Billions)  \
# 0              1             Roivant Sciences                0.123
# 1              2                     3i Group                0.707
# 2              3        Power Assets Holdings                0.165
# 3              4  Bajaj Holdings & Investment                0.207
# 4              5      Sichuan Chuantou Energy                0.201
#
#    Profit (in Billions)  Gross Profit Margin                Industry  \
# 0                4.5000          3658.536585   Drugs & Biotechnology
# 1                4.8000           678.925035  Diversified Financials
# 2                0.7668           464.727273               Utilities
# 3                0.8778           424.057971  Diversified Financials
# 4                0.6327           314.776119               Utilities
#
#           Country  Rank (in ATR)  Assets (in Billions)  Asset Turnover Ratio
# 0  United Kingdom           1966                   7.3              0.016849
# 1  United Kingdom           1951                  27.3              0.025897
# 2       Hong Kong           1981                  12.3              0.013415
# 3           India           1950                   7.8              0.026538
# 4           China           1955                   8.6              0.023372

# %%
analysis= pd.merge(analysis,ROA[['Rank (in ROA)','Name','Return on Assets']],
                   how = 'inner', on ='Name')
analysis.head()
# Out:
#    Rank (in GPM)                         Name  Sales (in Billions)  \
# 0              1             Roivant Sciences                0.123
# 1              2                     3i Group                0.707
# 2              3        Power Assets Holdings                0.165
# 3              4  Bajaj Holdings & Investment                0.207
# 4              5      Sichuan Chuantou Energy                0.201
#
#    Profit (in Billions)  Gross Profit Margin                Industry  \
# 0                4.5000          3658.536585   Drugs & Biotechnology
# 1                4.8000           678.925035  Diversified Financials
# 2                0.7668           464.727273               Utilities
# 3                0.8778           424.057971  Diversified Financials
# 4                0.6327           314.776119               Utilities
#
#           Country  Rank (in ATR)  Assets (in Billions)  Asset Turnover Ratio  \
# 0  United Kingdom           1966                   7.3              0.016849
# 1  United Kingdom           1951                  27.3              0.025897
# 2       Hong Kong           1981                  12.3              0.013415
# 3           India           1950                   7.8              0.026538
# 4           China           1955                   8.6              0.023372
#
#    Rank (in ROA)  Return on Assets
# 0              1          0.616438
# 1             78          0.175824
# 2            567          0.062341
# 3            234          0.112538
# 4            464          0.073570

# %%
analysis[(analysis['Rank (in GPM)']<300) & (analysis['Rank (in ATR)']<300) & (analysis['Rank (in ROA)']<300)]
# Out:
#      Rank (in GPM)                Name  Sales (in Billions)  \
# 138            139     Bayan Resources                  3.3
# 202            203               Apple                381.6
# 259            260  IDEXX Laboratories                  3.7
# 276            277         Yum! Brands                  7.0
#
#      Profit (in Billions)  Gross Profit Margin        Industry        Country  \
# 138                1.0000            30.303030       Materials      Indonesia
# 202              100.4000            26.310273  Semiconductors  United States
# 259                0.8666            23.421622      Healthcare  United States
# 276                1.6000            22.857143     Restaurants  United States
#
#      Rank (in ATR)  Assets (in Billions)  Asset Turnover Ratio  Rank (in ROA)  \
# 138            262                   2.9              1.137931              7
# 202            268                 337.4              1.131002             12
# 259            287                   3.4              1.088235             21
# 276            269                   6.2              1.129032             20
#
#      Return on Assets
# 138          0.344828
# 202          0.297570
# 259          0.254882
# 276          0.258065

# %% [markdown]
# ##### Findings:
# - 4 companies (`Bayan Resources`, `Apple`, `IDEXX Laboratories` & `Yum! Brands`) did well in managing pricing to gain profit and managing assets to convert into sales and profit.
